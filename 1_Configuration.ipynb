# %%
# %sql
CREATE CATALOG IF NOT EXISTS w_dev
MANAGED LOCATION 's3://wartsila-datalake-dev-managed-uc/';

# %%
# %sql
DROP SCHEMA IF EXISTS w_dev.bronze CASCADE;
DROP SCHEMA IF EXISTS w_dev.silver CASCADE;
DROP SCHEMA IF EXISTS w_dev.gold CASCADE;

# %%
# %sql

CREATE SCHEMA w_dev.bronze MANAGED LOCATION 's3://wartsila-datalake-dev-bronze/';
CREATE SCHEMA w_dev.silver MANAGED LOCATION 's3://wartsila-datalake-dev-silver/';
CREATE SCHEMA w_dev.gold   MANAGED LOCATION 's3://wartsila-datalake-dev-gold/';
-- CREATE SCHEMA w_dev.landing_admin MANAGED LOCATION 's3://wartsila-datalake-dev-landing'
